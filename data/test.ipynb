# %%
import numpy as np
import pandas as pd
from tvDatafeed import TvDatafeed, Interval
from matplotlib import pyplot as plt
import csv

# %%
# Indicators functions

# SMA :- Simple Moving Average.
def SMA(col: pd.Series, period: int = 50):
    """
    Calculate SMA using given column
    col : pd.Series
    period : int (default)
    """
    return col.rolling(period).mean().round(2)

# RSI :- Relative Strength Index.
def RSI(change : pd.Series, period: int = 14):
    """
    calculate RSI using price change data.
    change : pd.Sereies
    period : int
    """
    gain = change.where(change > 0, 0)
    loss = change.where(change < 0 , 0)
    loss = loss.abs()
    avgain = gain.rolling(period).mean()
    avloss = loss.rolling(period).mean()
    rs = avgain / avloss
    rsi = 100 - (100 / (1 + rs))
    return rsi.round(2)

# ADX :- Average Directional Index
def ADX(high, low, close, period:int = 14):
    TR = pd.DataFrame({
        'a': high - low,
        'b': abs(high - close.shift()),
        'c': abs(low - close.shift())
    }).max(axis=1)

    # Calculate the Directional Movement (DM)
    DMplus = (high - high.shift()) > (low.shift() - low)
    DMminus = (low.shift() - low) > (high - high.shift())

    # Calculate the True Directional Indicator (+DI) and (-DI)
    TR14 = TR.rolling(window=period).sum()
    DM14plus = DMplus.rolling(window=period).sum()
    DM14minus = DMminus.rolling(window=period).sum()

    DIplus14 = DM14plus / TR14 * 100
    DIminus14 = DM14minus / TR14 * 100

    # Calculate the Directional Movement Index (DMI)
    DX14 = abs(DIplus14 - DIminus14) / (DIplus14 + DIminus14) * 100
    ADX14 = DX14.rolling(window=period).mean()
    return ADX14.round(2)


# calcualte volume weigthed average price.
def VWAP(price: pd.Series, vol:pd.Series, period:int = 14) -> pd.Series:
    num = price * vol
    vmp = num.rolling(period).sum() 
    sv = vol.rolling(period).sum()
    return vmp/sv

# calcualting macd.
def MACD():
    pass

# %%
# WORK ON NIFTY 100.
n100 = pd.read_csv('niftymid100.csv', names = ['Symbol', 'Open', 'High', 'Low', 'Pre Close', 'LTP', 'Change', '%chng' , 'Vol', 'Value', '52W H' , '52W L' , '365D %c', '30D %c'])
n100sym = n100['Symbol']
n100sym
# Out:
# 0             SYMBOL \n
# 1      NIFTY MIDCAP 100
# 2              SONACOMS
# 3               MPHASIS
# 4             MAXHEALTH
#              ...
# 97                 SAIL
# 98                  OIL
# 99            POLICYBZR
# 100                BHEL
# 101            PRESTIGE
# Name: Symbol, Length: 102, dtype: object

# %%
# nifty 100
nft100 = pd.read_csv('nifty100.csv')
nft100.columns = ['SYMBOL', 'OPEN', 'HIGH', 'LOW', 'PREV. CLOSE', 'LTP',
       'CHNG', '%CHNG', 'VOLUME', 'VALUE ', '52W H',
       '52W L', '365 D % CHNG 25-May-2022',
       '30 D % CHNG \n 25-Apr-2023']

# %% [markdown]
# ### Initializing tvDatafeed

# %%
tv = TvDatafeed('mohitrathor7729', 'Mohit7729@#')
tv

# %% [markdown]
# ## Nifty 100 Stocks Scan
# ### Criteria :
# + Difference between 5 and 50 moving average should be minimum.

# %%
# short term trading scan
with open('NIFTY100-scan.csv', 'w') as fh:
    j = 1
    writer = csv.writer(fh)
    for i in nft100['SYMBOL']:
        try:
            data = tv.get_hist(symbol= i, exchange= 'NSE', interval= Interval.in_daily, n_bars = 200)
            data['MA5'] = SMA(data['close'], period= 5)
            data['MA50'] = SMA(data['close'])
            data['ADX']  = ADX(data['high'], data['low'], data['close'])
            writer.writerow(list(data.iloc[-1]))
            print(j)
            j += 1
        except Exception as e: print(e, i, 'Data unavailable !')
            
print('scan Completed !!!')
# Out:
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable NIFTY 100 Data unavailable !
# HDFCAMC
# can only concatenate str (not "int") to str HDFCAMC Data unavailable !
# HAL
# can only concatenate str (not "int") to str HAL Data unavailable !
# PAGEIND
# can only concatenate str (not "int") to str PAGEIND Data unavailable !
# ITC
# can only concatenate str (not "int") to str ITC Data unavailable !
# INDIGO
# can only concatenate str (not "int") to str INDIGO Data unavailable !
# HDFCLIFE
# can only concatenate str (not "int") to str HDFCLIFE Data unavailable !
# VEDL
# can only concatenate str (not "int") to str VEDL Data unavailable !
# BOSCHLTD
# can only concatenate str (not "int") to str BOSCHLTD Data unavailable !
# SIEMENS
# can only concatenate str (not "int") to str SIEMENS Data unavailable !
# SBICARD
# can only concatenate str (not "int") to str SBICARD Data unavailable !
# BERGEPAINT
# can only concatenate str (not "int") to str BERGEPAINT Data unavailable !
# BAJAJFINSV
# can only concatenate str (not "int") to str BAJAJFINSV Data unavailable !
# ICICIPRULI
# can only concatenate str (not "int") to str ICICIPRULI Data unavailable !
# SHREECEM
# can only concatenate str (not "int") to str SHREECEM Data unavailable !
# KOTAKBANK
# can only concatenate str (not "int") to str KOTAKBANK Data unavailable !
# BAJFINANCE
# can only concatenate str (not "int") to str BAJFINANCE Data unavailable !
# AMBUJACEM
# can only concatenate str (not "int") to str AMBUJACEM Data unavailable !
# INDUSTOWER
# can only concatenate str (not "int") to str INDUSTOWER Data unavailable !
# WIPRO
# can only concatenate str (not "int") to str WIPRO Data unavailable !
# HCLTECH
# can only concatenate str (not "int") to str HCLTECH Data unavailable !
# MARUTI
# can only concatenate str (not "int") to str MARUTI Data unavailable !
# ULTRACEMCO
# can only concatenate str (not "int") to str ULTRACEMCO Data unavailable !
# GRASIM
# can only concatenate str (not "int") to str GRASIM Data unavailable !
# INDUSINDBK
# can only concatenate str (not "int") to str INDUSINDBK Data unavailable !
# INFY
# can only concatenate str (not "int") to str INFY Data unavailable !
# AXISBANK
# can only concatenate str (not "int") to str AXISBANK Data unavailable !
# DABUR
# can only concatenate str (not "int") to str DABUR Data unavailable !
# JSWSTEEL
# can only concatenate str (not "int") to str JSWSTEEL Data unavailable !
# IOC
# can only concatenate str (not "int") to str IOC Data unavailable !
# HDFC
# can only concatenate str (not "int") to str HDFC Data unavailable !
# ICICIBANK
# can only concatenate str (not "int") to str ICICIBANK Data unavailable !
# HDFCBANK
# can only concatenate str (not "int") to str HDFCBANK Data unavailable !
# CIPLA
# can only concatenate str (not "int") to str CIPLA Data unavailable !
# ACC
# can only concatenate str (not "int") to str ACC Data unavailable !
# POWERGRID
# can only concatenate str (not "int") to str POWERGRID Data unavailable !
# DMART
# can only concatenate str (not "int") to str DMART Data unavailable !
# HINDUNILVR
# can only concatenate str (not "int") to str HINDUNILVR Data unavailable !
# PIDILITIND
# can only concatenate str (not "int") to str PIDILITIND Data unavailable !
# LTIM
# can only concatenate str (not "int") to str LTIM Data unavailable !
# CANBK
# can only concatenate str (not "int") to str CANBK Data unavailable !
# ASIANPAINT
# can only concatenate str (not "int") to str ASIANPAINT Data unavailable !
# NTPC
# can only concatenate str (not "int") to str NTPC Data unavailable !
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable MCDOWELL-N Data unavailable !
# MUTHOOTFIN
# can only concatenate str (not "int") to str MUTHOOTFIN Data unavailable !
# TORNTPHARM
# can only concatenate str (not "int") to str TORNTPHARM Data unavailable !
# ONGC
# can only concatenate str (not "int") to str ONGC Data unavailable !
# RELIANCE
# can only concatenate str (not "int") to str RELIANCE Data unavailable !
# BANKBARODA
# can only concatenate str (not "int") to str BANKBARODA Data unavailable !
# BRITANNIA
# can only concatenate str (not "int") to str BRITANNIA Data unavailable !
# PGHH
# can only concatenate str (not "int") to str PGHH Data unavailable !
# UPL
# can only concatenate str (not "int") to str UPL Data unavailable !
# TCS
# can only concatenate str (not "int") to str TCS Data unavailable !
# TATAPOWER
# can only concatenate str (not "int") to str TATAPOWER Data unavailable !
# HEROMOTOCO
# can only concatenate str (not "int") to str HEROMOTOCO Data unavailable !
# GODREJCP
# can only concatenate str (not "int") to str GODREJCP Data unavailable !
# SBILIFE
# can only concatenate str (not "int") to str SBILIFE Data unavailable !
# ABB
# can only concatenate str (not "int") to str ABB Data unavailable !
# MARICO
# can only concatenate str (not "int") to str MARICO Data unavailable !
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable M&M Data unavailable !
# BEL
# can only concatenate str (not "int") to str BEL Data unavailable !
# BHARTIARTL
# can only concatenate str (not "int") to str BHARTIARTL Data unavailable !
# SBIN
# can only concatenate str (not "int") to str SBIN Data unavailable !
# TITAN
# can only concatenate str (not "int") to str TITAN Data unavailable !
# BPCL
# can only concatenate str (not "int") to str BPCL Data unavailable !
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable BAJAJ-AUTO Data unavailable !
# TATAMOTORS
# can only concatenate str (not "int") to str TATAMOTORS Data unavailable !
# GAIL
# can only concatenate str (not "int") to str GAIL Data unavailable !
# ADANIPORTS
# can only concatenate str (not "int") to str ADANIPORTS Data unavailable !
# IRCTC
# can only concatenate str (not "int") to str IRCTC Data unavailable !
# LT
# can only concatenate str (not "int") to str LT Data unavailable !
# TATACONSUM
# can only concatenate str (not "int") to str TATACONSUM Data unavailable !
# ZOMATO
# can only concatenate str (not "int") to str ZOMATO Data unavailable !
# COALINDIA
# can only concatenate str (not "int") to str COALINDIA Data unavailable !
# DIVISLAB
# can only concatenate str (not "int") to str DIVISLAB Data unavailable !
# NESTLEIND
# can only concatenate str (not "int") to str NESTLEIND Data unavailable !
# SRF
# can only concatenate str (not "int") to str SRF Data unavailable !
# ICICIGI
# can only concatenate str (not "int") to str ICICIGI Data unavailable !
# HAVELLS
# can only concatenate str (not "int") to str HAVELLS Data unavailable !
# SUNPHARMA
# can only concatenate str (not "int") to str SUNPHARMA Data unavailable !
# NYKAA
# can only concatenate str (not "int") to str NYKAA Data unavailable !
# APOLLOHOSP
# can only concatenate str (not "int") to str APOLLOHOSP Data unavailable !
# LICI
# can only concatenate str (not "int") to str LICI Data unavailable !
# EICHERMOT
# can only concatenate str (not "int") to str EICHERMOT Data unavailable !
# CHOLAFIN
# can only concatenate str (not "int") to str CHOLAFIN Data unavailable !
# COLPAL
# can only concatenate str (not "int") to str COLPAL Data unavailable !
# PIIND
# can only concatenate str (not "int") to str PIIND Data unavailable !
# DRREDDY
# can only concatenate str (not "int") to str DRREDDY Data unavailable !
# TECHM
# can only concatenate str (not "int") to str TECHM Data unavailable !
# MOTHERSON
# can only concatenate str (not "int") to str MOTHERSON Data unavailable !
# ADANIGREEN
# can only concatenate str (not "int") to str ADANIGREEN Data unavailable !
# TATASTEEL
# can only concatenate str (not "int") to str TATASTEEL Data unavailable !
# ADANIENT
# can only concatenate str (not "int") to str ADANIENT Data unavailable !
# HINDALCO
# can only concatenate str (not "int") to str HINDALCO Data unavailable !
# DLF
# can only concatenate str (not "int") to str DLF Data unavailable !
# BAJAJHLDNG
# can only concatenate str (not "int") to str BAJAJHLDNG Data unavailable !
# VBL
# can only concatenate str (not "int") to str VBL Data unavailable !
# ADANITRANS
# can only concatenate str (not "int") to str ADANITRANS Data unavailable !
# AWL
# can only concatenate str (not "int") to str AWL Data unavailable !
# NAUKRI
# can only concatenate str (not "int") to str NAUKRI Data unavailable !
# ATGL
# can only concatenate str (not "int") to str ATGL Data unavailable !

# %%
scanN100 = pd.read_csv('NIFTY100-scan.csv', names = ['symbol', 'open', 'high', 'low', 'close', 'vol', 'MA5', 'MA50', "RSI"])
scanN100['MA_DIFF'] = (scanN100['MA5'] - scanN100['MA50']) / scanN100['MA50'] * 100
# scanN100['MA_DIFF'] = np.array(list(map(abs, scanN100['MA_DIFF'])))
scanN100 = scanN100.where(scanN100['MA_DIFF'] <= 0)
scanN100.sort_values('MA_DIFF').head(20)
# Out:
#             symbol         open         high          low        close  \
# 96        NSE:ATGL    658.00000    658.00000    630.00000    634.29999
# 93  NSE:ADANITRANS    804.40002    804.40002    738.00000    757.50000
# 72         NSE:SRF   2379.25000   2379.25000   2305.10010   2321.39990
# 14   NSE:KOTAKBANK   1833.00000   1845.55000   1823.90000   1828.55000
# 2      NSE:PAGEIND  38186.00000  38186.00000  37333.55100  37676.50000
# 69   NSE:COALINDIA    227.10001    227.55000    224.80000    225.89999
# 49         NSE:UPL    674.75000    675.75000    665.50000    666.84998
# 59        NSE:SBIN    562.00000    562.09998    553.79999    554.59998
# 44        NSE:ONGC    159.00000    159.00000    155.39999    156.89999
# 18       NSE:WIPRO    382.29999    383.00000    378.10001    379.95001
# 39       NSE:CANBK    301.20001    301.70001    294.60001    296.39999
# 31    NSE:HDFCBANK   1637.55000   1659.90000   1634.05000   1643.50000
# 63        NSE:GAIL    104.35000    105.40000    103.30000    105.05000
# 29        NSE:HDFC   2701.14990   2742.70000   2700.55000   2723.14990
# 30   NSE:ICICIBANK    926.04999    931.90002    919.00000    923.50000
# 89    NSE:HINDALCO    416.00000    416.95001    407.45001    408.50000
# 6         NSE:VEDL    280.85001    280.85001    275.89999    276.20001
# 94         NSE:AWL    416.70001    416.89999    402.10001    404.00000
# 50         NSE:TCS   3237.30000   3249.39990   3209.14990   3216.35010
# 7     NSE:BOSCHLTD  18879.30100  18959.69900  18490.05100  18616.94900
#
#            vol       MA5      MA50    RSI    MA_DIFF
# 96   2019933.0    652.28    779.78  16.33 -16.350766
# 93   2777512.0    797.43    884.83  12.24  -9.877604
# 72    678470.0   2377.69   2479.28  24.49  -4.097561
# 14   2584063.0   1835.75   1911.08  31.63  -3.941750
# 2      16827.0  38270.71  39823.76  18.37  -3.899808
# 69   3881707.0    227.14    233.51  12.24  -2.727935
# 49   1884124.0    679.28    697.66  27.55  -2.634521
# 59  12215712.0    564.03    572.57  27.55  -1.491521
# 44   8722650.0    158.22    160.45  25.51  -1.389841
# 18   3235203.0    382.08    386.61  29.59  -1.171723
# 39   4739916.0    303.07    305.83  18.37  -0.902462
# 31  10669609.0   1626.87   1640.84  10.20  -0.851393
# 63   7880417.0    106.49    107.37  15.31  -0.819596
# 29   3089041.0   2690.88   2710.17  11.22  -0.711763
# 30   8767733.0    924.53    930.40  26.53  -0.630911
# 89   5403772.0    420.92    421.89  15.31  -0.229918
# 6    5178936.0    280.26    280.87  10.20  -0.217182
# 94   1944691.0    415.42    416.18  51.02  -0.182613
# 50   1119505.0   3230.23   3234.92  17.35  -0.144980
# 7      30239.0  18940.06  18960.51  22.45  -0.107856

# %%
# btst scan
for i in nft100['SYMBOL']:
    try:
        data = tv.get_hist(symbol= i, exchange= 'NSE', interval= Interval.in_5_minute, n_bars = 1000)
        data['MA20'] = SMA(data['close'], period= 20)
        data['MA50'] = SMA(data['close'])
        data['ADX']  = ADX(data['high'], data['low'], data['close'])
        data['CORR'] = data['MA20'].iloc[-75:].corr(data['MA50'].iloc[-75:])
        if data['CORR'].iloc[-1] > 0.75 and data['ADX'].iloc[-1] > 25:
            print(list(data.iloc[-1]))
    except Exception as e: print(e, i, 'Data unavailable !')
# Out:
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable NIFTY 100 Data unavailable !
# ['NSE:HAL', 3765.15, 3771.0, 3762.0, 3771.0, 12240.0, 3755.24, 3718.76, 29.59, 0.9734309190043567]
# ['NSE:PAGEIND', 37997.05, 38020.0, 37980.9, 38020.0, 270.0, 38238.1, 38496.37, 28.57, 0.9877967845491527]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       2 for i in nft100['SYMBOL']:
#       3     try:
# ----> 4         data = tv.get_hist(symbol= i, exchange= 'NSE', interval= Interval.in_5_minute, n_bars = 1000)
#       5         data['MA20'] = SMA(data['close'], period= 20)
#       6         data['MA50'] = SMA(data['close'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tvDatafeed\main.py:290, in TvDatafeed.get_hist(self, symbol, exchange, interval, n_bars, fut_contract, extended_session)
#     287     if "series_completed" in result:
#     288         break
# --> 290 return self.__create_df(raw_data, symbol)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tvDatafeed\main.py:136, in TvDatafeed.__create_df(raw_data, symbol)
#     133 @staticmethod
#     134 def __create_df(raw_data, symbol):
#     135     try:
# --> 136         out = re.search('"s":\[(.+?)\}\]', raw_data).group(1)
#     137         x = out.split(',{"')
#     138         data = list()
#
# KeyboardInterrupt:

# %%
data = tv.get_hist(symbol= 'SBIN', exchange= 'NSE', interval= Interval.in_5_minute, n_bars = 1000)
data
# Out:
#                        symbol    open    high     low   close    volume
# datetime
# 2023-06-06 13:25:00  NSE:SBIN  584.15  584.40  583.80  584.10   94207.0
# 2023-06-06 13:30:00  NSE:SBIN  584.10  584.80  584.05  584.70  111156.0
# 2023-06-06 13:35:00  NSE:SBIN  584.70  584.85  584.35  584.55   48117.0
# 2023-06-06 13:40:00  NSE:SBIN  584.50  584.85  584.10  584.70   48688.0
# 2023-06-06 13:45:00  NSE:SBIN  584.80  585.10  584.50  584.55  147608.0
# ...                       ...     ...     ...     ...     ...       ...
# 2023-06-23 15:05:00  NSE:SBIN  554.85  555.20  554.75  555.10  264960.0
# 2023-06-23 15:10:00  NSE:SBIN  555.30  555.30  554.45  554.75  251691.0
# 2023-06-23 15:15:00  NSE:SBIN  554.65  555.00  554.00  554.25  467049.0
# 2023-06-23 15:20:00  NSE:SBIN  554.20  554.45  553.80  554.35  430050.0
# 2023-06-23 15:25:00  NSE:SBIN  554.30  555.30  554.20  555.05  243871.0
#
# [1000 rows x 6 columns]

# %%
data  = tv.get_hist(symbol = 'SBIN', exchange = 'NSE', interval = Interval.in_1_minute, n_bars = 5000)
data['SMA5'] = SMA(data['close'], period = 5)
data['SMA25'] = SMA(data['close'], period = 25)
data['RSI']  = RSI(data['close']-data['open'], period= 14)
data['ADX'] = ADX(data['high'], data['low'], data['close'])
data['VAR'] = data['close'].rolling(20).var()
data['MA COV'] = data['SMA25'].rolling(20).corr(data['SMA5'])
data['CORR'] = data['MA COV'].rolling(20).corr(data['close'])
data.iloc[100:]

# %%
d = np.array(data)
d = d[100:]
d[1][6] > d[1][7]

# %%
cap = 1000000
q = lambda p, c : round(c/p)
in_trade = False
profit = 0
used_cap = 0
Q = 0

for i in d:
    print(i)
    if i[6]>i[7] and i[6]<i[7] and (not in_trade):  # buy case
        in_trade = True
        qnty = q(d[i][4], cap)
        used_cap = qnty * d[i][4]
        Q = qnty
        
    elif i[6]<i[7] and i[6]>i[7] and (not in_trade):# sell case
        in_trade = True
        qnty = q(d[i][4], cap)
        used_cap = qnty * d[i][4]
        Q = qnty
        
    elif i[6]<i[7] and i[6]>i[7] and (in_trade):  # buy case
        in_trade = False
        profit += Q * d[i][4] - used_cap
        in_trade = True
        qnty = q(d[i][4], cap)
        used_cap = qnty * d[i][4]
        Q = qnty
        
    elif i[6]>i[7] and i[6]<i[7] and (not in_trade): # sell case
        in_trade = False
        profit += used_cap - Q * d[i][4]
        in_trade = True
        qnty = q(d[i][4], cap)
        used_cap = qnty * d[i][4]
        Q = qnty
    

        
print('Profit Gained : ', profit)
print("% profit : " , round(profit/cap*100, 2) )

# %%
 count = 0
with open('scandata.csv', 'w') as fh:
    writer = csv.writer(fh)
    writer.writerow('symbol open high low close volume SMA5 SMA25 RSI ADX VAR MACOV CORR'.split())
    for i in n100sym:
        try:
            data  = tv.get_hist(symbol = i , exchange = 'NSE', interval = Interval.in_daily, n_bars = 100)
            data['SMA5'] = SMA(data['close'], period = 5)
            data['SMA25'] = SMA(data['close'], period = 25)
            data['RSI']  = RSI(data['close']-data['open'], period= 14)
            data['ADX'] = ADX(data['high'], data['low'], data['close'])
            data['VAR'] = data['close'].rolling(20).var()
            data['MA COV'] = data['SMA25'].rolling(20).corr(data['SMA5'])
            data['CORR'] = data['MA COV'].rolling(20).corr(data['close'])
            writer.writerow(list(data.iloc[-1]))
            count += 1
            print(i, count)
        except:
            count += 1
            print(i,count,'-NOT ACSSIABLE!')

# %%
new  = pd.read_csv('scandata.csv')
new[new['CORR'] > 0.75]

# %%
new[new['CORR'] < -0.75]

# %% [markdown]
# # Stretegy Testing:

# %%
# Base program

in_cap = 1000000                                                            #  total  investable amount
capital = 1000000
qnty = lambda cap,price : round(cap/price)               #  calculate quantity to be buy or sell
in_trade = False                                                               #  show that in a trade or not
trade_info = {
    'capital' : 1000000,
    'buy price' : 0,
    'sell price'  : 0,
    'quantity' : 0,
    'profit / lose' : 0
}                                                           #  give trade inforamtion like buy /  sell price stoploss capital used etc.

# %%
round(20.46546544)

# %% [markdown]
# ## 5 min scan

# %%
with open('5-min-NIFTY100-scan.csv', 'w') as fh:
    j = 1
    writer = csv.writer(fh)
    writer.writerow(['symbol', 'open', 'high' , 'low', 'close', 'MA5', 'MA50', 'ADX', 'RSI', 'RSIMA100'])
    for i in nft100['SYMBOL']:
        try:
            data = tv.get_hist(symbol= i, exchange= 'NSE', interval= Interval.in_5_minute, n_bars = 200)
            data['MA5'] = SMA(data['close'], period= 5)
            data['MA50'] = SMA(data['close'])
            data['ADX']  = ADX(data['high'], data['low'], data['close'])
            data['RSI'] = RSI(data['close']-data['open'])
            data['RSIMA100'] = SMA(data['RSI'], period = 100)
            writer.writerow(list(data.iloc[-1]))
            if -1 < ((data.iloc[-1]['MA5'] - data.iloc[-1]['MA50']) / data.iloc[-1]['MA50']) < 1 and data.iloc[-1]['close'] < 1000:
                if (data.iloc[-1]['RSI'] > data.iloc[-1]['RSIMA100'] and data.iloc[-1]['RSI'] > 55) :
                    print('BULLISH : - ')
                    print(data.iloc[-1])
                elif (data.iloc[-1]['RSI'] < data.iloc[-1]['RSIMA100'] and data.iloc[-1]['RSI'] < 45) : 
                    print('BEARISH : - ')
                    print(data.iloc[-1])
            print(j)
            j += 1
        except Exception as e: print(e, i, 'Data unavailable !')
            
print('scan Completed !!!')
# Out:
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable NIFTY 100 Data unavailable !
# symbol      NSE:HDFCAMC
# open             2063.5
# high            2066.05
# low              2062.8
# close            2065.0
# volume          13010.0
# MA5             2057.79
# MA50            2048.57
# ADX               18.37
# RSI               65.83
# RSIMA100          60.08
# Name: 2023-06-28 11:20:00, dtype: object
# 1
# symbol      NSE:HAL
# open         3682.0
# high        3683.25
# low          3681.0
# close        3682.0
# volume       5644.0
# MA5          3685.4
# MA50         3684.9
# ADX           20.41
# RSI            31.7
# RSIMA100      45.34
# Name: 2023-06-28 11:20:00, dtype: object
# 2
# 3
# symbol      NSE:ITC
# open         448.35
# high          448.5
# low          448.35
# close         448.4
# volume      33151.0
# MA5          447.89
# MA50         446.28
# ADX           19.39
# RSI           64.71
# RSIMA100      49.62
# Name: 2023-06-28 11:20:00, dtype: object
# 4
# symbol      NSE:INDIGO
# open           2570.65
# high            2574.0
# low             2569.3
# close           2572.4
# volume          2840.0
# MA5            2571.72
# MA50           2547.23
# ADX              30.61
# RSI              61.85
# RSIMA100         60.29
# Name: 2023-06-28 11:20:00, dtype: object
# 5
# symbol      NSE:HDFCLIFE
# open              658.35
# high              659.85
# low                658.1
# close              659.2
# volume           73112.0
# MA5                659.4
# MA50              661.41
# ADX                11.22
# RSI                34.57
# RSIMA100           57.06
# Name: 2023-06-28 11:20:00, dtype: object
# 6
# symbol      NSE:VEDL
# open           279.8
# high           279.8
# low           279.55
# close         279.65
# volume       26795.0
# MA5           279.73
# MA50          279.79
# ADX            19.11
# RSI            41.67
# RSIMA100       46.06
# Name: 2023-06-28 11:20:00, dtype: object
# 7
# symbol      NSE:BOSCHLTD
# open             18520.0
# high            18528.65
# low              18519.4
# close           18519.95
# volume              82.0
# MA5             18524.03
# MA50            18560.06
# ADX                36.73
# RSI                22.53
# RSIMA100           46.46
# Name: 2023-06-28 11:20:00, dtype: object
# 8
# symbol      NSE:SIEMENS
# open             3684.1
# high            3684.45
# low              3682.3
# close            3683.0
# volume            586.0
# MA5             3687.84
# MA50            3704.12
# ADX               43.88
# RSI               18.86
# RSIMA100          40.56
# Name: 2023-06-28 11:20:00, dtype: object
# 9
# symbol      NSE:SBICARD
# open             866.25
# high             867.55
# low              866.25
# close            866.75
# volume          14882.0
# MA5              865.71
# MA50             864.07
# ADX               17.35
# RSI               37.04
# RSIMA100          53.32
# Name: 2023-06-28 11:20:00, dtype: object
# 10
# symbol      NSE:BERGEPAINT
# open                677.45
# high                 677.9
# low                  677.1
# close                677.1
# volume              1170.0
# MA5                 678.04
# MA50                677.76
# ADX                  13.34
# RSI                   56.0
# RSIMA100              44.7
# Name: 2023-06-28 11:20:00, dtype: object
# 11
# symbol      NSE:BAJAJFINSV
# open               1529.05
# high               1529.05
# low                1527.85
# close               1528.0
# volume              3343.0
# MA5                1527.31
# MA50               1524.06
# ADX                  18.37
# RSI                   36.7
# RSIMA100             54.62
# Name: 2023-06-28 11:20:00, dtype: object
# 12
# 13
# symbol      NSE:SHREECEM
# open             23963.7
# high            23974.95
# low              23963.7
# close            23965.0
# volume             125.0
# MA5              23938.6
# MA50            23967.27
# ADX                30.61
# RSI                24.64
# RSIMA100           45.76
# Name: 2023-06-28 11:20:00, dtype: object
# 14
# symbol      NSE:KOTAKBANK
# open               1837.6
# high               1839.4
# low                1836.0
# close              1839.0
# volume            25338.0
# MA5               1837.62
# MA50              1836.52
# ADX                 19.39
# RSI                  60.0
# RSIMA100            53.17
# Name: 2023-06-28 11:20:00, dtype: object
# 15
# 16
# symbol      NSE:AMBUJACEM
# open                439.4
# high               439.45
# low                 438.8
# close              439.05
# volume            15021.0
# MA5                439.44
# MA50               436.88
# ADX                 27.55
# RSI                 33.73
# RSIMA100            52.61
# Name: 2023-06-28 11:20:00, dtype: object
# 17
# symbol      NSE:INDUSTOWER
# open                165.85
# high                 166.5
# low                 165.85
# close                166.1
# volume            256103.0
# MA5                 164.89
# MA50                163.23
# ADX                   11.3
# RSI                  59.56
# RSIMA100              47.7
# Name: 2023-06-28 11:20:00, dtype: object
# 18
# symbol      NSE:WIPRO
# open           381.85
# high           381.95
# low             381.8
# close          381.95
# volume        16015.0
# MA5            381.99
# MA50           382.44
# ADX             26.32
# RSI             41.94
# RSIMA100        48.87
# Name: 2023-06-28 11:20:00, dtype: object
# 19
# symbol      NSE:HCLTECH
# open             1170.8
# high             1171.7
# low              1170.4
# close           1171.25
# volume           3910.0
# MA5             1170.99
# MA50            1170.31
# ADX               15.31
# RSI               62.36
# RSIMA100          49.17
# Name: 2023-06-28 11:20:00, dtype: object
# 20
# 21
# symbol      NSE:ULTRACEMCO
# open                8219.8
# high                8220.0
# low                8215.05
# close               8219.9
# volume              1553.0
# MA5                 8219.6
# MA50               8209.59
# ADX                  13.27
# RSI                  55.66
# RSIMA100             50.79
# Name: 2023-06-28 11:20:00, dtype: object
# 22
# symbol      NSE:GRASIM
# open            1745.8
# high            1747.0
# low            1744.85
# close           1746.6
# volume          2993.0
# MA5            1747.28
# MA50           1737.34
# ADX              28.57
# RSI              29.53
# RSIMA100         59.63
# Name: 2023-06-28 11:20:00, dtype: object
# 23
# symbol      NSE:INDUSINDBK
# open                1330.5
# high                1333.9
# low                 1329.4
# close               1333.9
# volume             41171.0
# MA5                1330.69
# MA50               1318.38
# ADX                   7.14
# RSI                  83.54
# RSIMA100             51.45
# Name: 2023-06-28 11:20:00, dtype: object
# 24
# symbol      NSE:INFY
# open         1290.15
# high         1290.85
# low          1290.05
# close         1290.8
# volume       21884.0
# MA5          1289.55
# MA50         1282.13
# ADX            36.73
# RSI            88.77
# RSIMA100       46.25
# Name: 2023-06-28 11:20:00, dtype: object
# 25
# symbol      NSE:AXISBANK
# open              972.85
# high              974.85
# low               972.85
# close              974.5
# volume           51737.0
# MA5                973.1
# MA50              970.99
# ADX                22.45
# RSI                78.33
# RSIMA100           57.01
# Name: 2023-06-28 11:20:00, dtype: object
# 26
# 27
# 28
# symbol      NSE:IOC
# open          89.45
# high           89.6
# low            89.4
# close          89.6
# volume      59826.0
# MA5           89.41
# MA50          89.49
# ADX           46.22
# RSI            40.0
# RSIMA100      42.73
# Name: 2023-06-28 11:20:00, dtype: object
# 29
# symbol      NSE:HDFC
# open         2767.75
# high          2770.0
# low           2767.0
# close        2769.45
# volume       26835.0
# MA5          2767.22
# MA50         2762.33
# ADX            15.31
# RSI            60.12
# RSIMA100       57.57
# Name: 2023-06-28 11:20:00, dtype: object
# 30
# symbol      NSE:ICICIBANK
# open               938.15
# high               939.95
# low                 938.0
# close              939.95
# volume           154184.0
# MA5                938.26
# MA50               934.81
# ADX                 20.41
# RSI                 61.02
# RSIMA100            53.39
# Name: 2023-06-28 11:20:00, dtype: object
# 31
# symbol      NSE:HDFCBANK
# open             1669.25
# high             1670.45
# low              1668.25
# close            1670.25
# volume          153103.0
# MA5              1669.24
# MA50             1663.02
# ADX                 8.16
# RSI                76.55
# RSIMA100           58.42
# Name: 2023-06-28 11:20:00, dtype: object
# 32
# symbol      NSE:CIPLA
# open           1009.8
# high          1010.45
# low           1007.35
# close          1008.5
# volume        60284.0
# MA5           1009.42
# MA50          1008.78
# ADX             18.63
# RSI             59.44
# RSIMA100        50.62
# Name: 2023-06-28 11:20:00, dtype: object
# 33
# 34
# symbol      NSE:POWERGRID
# open               251.25
# high                251.4
# low                 251.2
# close               251.3
# volume            46589.0
# MA5                251.12
# MA50               249.72
# ADX                 33.36
# RSI                 57.38
# RSIMA100            53.07
# Name: 2023-06-28 11:20:00, dtype: object
# 35
# symbol      NSE:DMART
# open           3875.5
# high           3877.5
# low            3875.0
# close          3877.0
# volume          300.0
# MA5           3876.45
# MA50          3871.26
# ADX             17.53
# RSI             43.37
# RSIMA100        48.42
# Name: 2023-06-28 11:20:00, dtype: object
# 36
# symbol      NSE:HINDUNILVR
# open                2656.1
# high                2657.1
# low                 2656.0
# close               2656.6
# volume              8576.0
# MA5                2655.78
# MA50                2653.7
# ADX                  21.43
# RSI                  57.69
# RSIMA100             51.14
# Name: 2023-06-28 11:20:00, dtype: object
# 37
# 38
# symbol      NSE:LTIM
# open          5157.4
# high         5158.25
# low           5148.1
# close        5149.95
# volume        1195.0
# MA5          5150.94
# MA50         5123.02
# ADX            20.41
# RSI            31.89
# RSIMA100        50.6
# Name: 2023-06-28 11:20:00, dtype: object
# 39
# symbol      NSE:CANBK
# open           297.65
# high            298.0
# low             297.6
# close           298.0
# volume        16425.0
# MA5             297.8
# MA50           296.63
# ADX              6.12
# RSI             60.71
# RSIMA100        52.06
# Name: 2023-06-28 11:20:00, dtype: object
# 40
# symbol      NSE:ASIANPAINT
# open                3343.0
# high                3345.0
# low                 3342.9
# close               3344.1
# volume              3587.0
# MA5                3342.57
# MA50               3327.24
# ADX                  26.53
# RSI                   70.9
# RSIMA100             51.45
# Name: 2023-06-28 11:20:00, dtype: object
# 41
# symbol      NSE:NTPC
# open           188.4
# high           188.4
# low            187.9
# close          188.2
# volume      104832.0
# MA5           187.94
# MA50          186.34
# ADX            71.36
# RSI            74.44
# RSIMA100       55.49
# Name: 2023-06-28 11:20:00, dtype: object
# 42
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable MCDOWELL-N Data unavailable !
# symbol      NSE:MUTHOOTFIN
# open                1238.4
# high               1238.95
# low                1237.75
# close               1238.0
# volume              1083.0
# MA5                1236.21
# MA50                1238.6
# ADX                  18.37
# RSI                  41.75
# RSIMA100             49.75
# Name: 2023-06-28 11:20:00, dtype: object
# 43
# symbol      NSE:TORNTPHARM
# open               1884.15
# high               1888.85
# low                1884.15
# close               1888.8
# volume               524.0
# MA5                1886.53
# MA50               1879.49
# ADX                  25.55
# RSI                  72.69
# RSIMA100              45.6
# Name: 2023-06-28 11:20:00, dtype: object
# 44
# symbol      NSE:ONGC
# open          158.95
# high           159.1
# low            158.9
# close          159.0
# volume       73280.0
# MA5           158.76
# MA50           158.0
# ADX            53.06
# RSI            82.76
# RSIMA100       53.82
# Name: 2023-06-28 11:20:00, dtype: object
# 45
# symbol      NSE:RELIANCE
# open             2522.95
# high             2523.25
# low               2522.5
# close             2523.0
# volume           19496.0
# MA5              2522.78
# MA50             2504.68
# ADX                19.39
# RSI                 67.8
# RSIMA100           51.91
# Name: 2023-06-28 11:20:00, dtype: object
# 46
# 47
# symbol      NSE:BRITANNIA
# open              4997.15
# high               5001.0
# low               4995.45
# close             4999.15
# volume             1430.0
# MA5               4992.47
# MA50              4969.78
# ADX                 13.27
# RSI                 79.35
# RSIMA100            42.33
# Name: 2023-06-28 11:20:00, dtype: object
# 48
# symbol      NSE:PGHH
# open        14323.55
# high        14324.65
# low          14300.4
# close        14300.4
# volume          11.0
# MA5         14319.34
# MA50        14342.61
# ADX            33.67
# RSI            78.02
# RSIMA100       47.91
# Name: 2023-06-28 11:20:00, dtype: object
# 49
# symbol      NSE:UPL
# open         674.95
# high          675.6
# low           674.8
# close         675.4
# volume      33875.0
# MA5          675.11
# MA50         674.65
# ADX           24.49
# RSI           78.18
# RSIMA100      44.64
# Name: 2023-06-28 11:20:00, dtype: object
# 50
# symbol      NSE:TCS
# open         3208.2
# high        3209.95
# low          3208.0
# close       3209.95
# volume       5363.0
# MA5         3207.41
# MA50         3196.5
# ADX           28.57
# RSI           76.57
# RSIMA100       48.7
# Name: 2023-06-28 11:20:00, dtype: object
# 51
# 52
# symbol      NSE:HEROMOTOCO
# open                2803.5
# high                2810.0
# low                 2802.0
# close              2809.45
# volume              8218.0
# MA5                2811.05
# MA50               2835.78
# ADX                   10.2
# RSI                  26.17
# RSIMA100             48.34
# Name: 2023-06-28 11:20:00, dtype: object
# 53
# symbol      NSE:GODREJCP
# open             1036.25
# high              1040.5
# low              1035.95
# close             1040.5
# volume           40952.0
# MA5              1038.14
# MA50              1036.4
# ADX                17.11
# RSI                66.15
# RSIMA100           45.91
# Name: 2023-06-28 11:20:00, dtype: object
# 54
# symbol      NSE:SBILIFE
# open            1297.95
# high            1303.15
# low              1297.4
# close            1303.0
# volume          30419.0
# MA5             1297.53
# MA50            1285.04
# ADX               37.76
# RSI                86.7
# RSIMA100          59.14
# Name: 2023-06-28 11:20:00, dtype: object
# 55
# symbol      NSE:ABB
# open         4304.5
# high         4310.0
# low          4304.1
# close        4308.4
# volume       1435.0
# MA5         4305.64
# MA50        4301.46
# ADX           11.22
# RSI           31.49
# RSIMA100      42.16
# Name: 2023-06-28 11:20:00, dtype: object
# 56
# 57
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable M&M Data unavailable !
# symbol      NSE:BEL
# open         118.75
# high         118.75
# low          118.45
# close        118.55
# volume      98047.0
# MA5          118.66
# MA50         118.81
# ADX           48.27
# RSI           31.58
# RSIMA100      35.77
# Name: 2023-06-28 11:20:00, dtype: object
# 58
# symbol      NSE:BHARTIARTL
# open                 867.3
# high                867.85
# low                 866.85
# close               867.05
# volume             47463.0
# MA5                 867.03
# MA50                866.21
# ADX                  18.37
# RSI                  24.71
# RSIMA100             50.41
# Name: 2023-06-28 11:20:00, dtype: object
# 59
# symbol      NSE:SBIN
# open           572.3
# high           573.0
# low           571.95
# close         572.85
# volume      213780.0
# MA5           572.47
# MA50          566.15
# ADX            27.86
# RSI            88.33
# RSIMA100       53.56
# Name: 2023-06-28 11:20:00, dtype: object
# 60
# symbol      NSE:TITAN
# open          3023.65
# high          3025.95
# low           3022.55
# close         3025.75
# volume         4266.0
# MA5           3022.88
# MA50          2990.57
# ADX             14.29
# RSI             64.38
# RSIMA100        62.03
# Name: 2023-06-28 11:20:00, dtype: object
# 61
# symbol      NSE:BPCL
# open           363.0
# high           363.3
# low           362.85
# close          363.2
# volume       40609.0
# MA5           362.27
# MA50          360.82
# ADX            17.82
# RSI             87.5
# RSIMA100       51.84
# Name: 2023-06-28 11:20:00, dtype: object
# 62
# ERROR:tvDatafeed.main:Connection timed out
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# 'NoneType' object is not subscriptable BAJAJ-AUTO Data unavailable !
# symbol      NSE:TATAMOTORS
# open                585.35
# high                586.45
# low                  585.3
# close                586.0
# volume            192244.0
# MA5                 586.57
# MA50                576.72
# ADX                  36.73
# RSI                  71.51
# RSIMA100             51.23
# Name: 2023-06-28 11:20:00, dtype: object
# 63
# symbol      NSE:GAIL
# open          104.35
# high          104.45
# low           104.25
# close         104.45
# volume       87184.0
# MA5           104.42
# MA50          104.25
# ADX            20.09
# RSI            59.26
# RSIMA100       46.19
# Name: 2023-06-28 11:20:00, dtype: object
# 64
# symbol      NSE:ADANIPORTS
# open                 740.0
# high                 740.2
# low                 739.55
# close                740.1
# volume             97420.0
# MA5                 739.37
# MA50                727.57
# ADX                  26.53
# RSI                  75.07
# RSIMA100             48.35
# Name: 2023-06-28 11:20:00, dtype: object
# 65
# 66
# symbol       NSE:LT
# open         2414.6
# high        2416.75
# low          2413.6
# close       2416.75
# volume       9688.0
# MA5          2415.9
# MA50        2398.36
# ADX            46.7
# RSI           77.46
# RSIMA100      52.65
# Name: 2023-06-28 11:20:00, dtype: object
# 67
# symbol      NSE:TATACONSUM
# open                 856.6
# high                 858.0
# low                  856.2
# close               857.85
# volume              8942.0
# MA5                 856.71
# MA50                 855.3
# ADX                  12.28
# RSI                  64.23
# RSIMA100             43.64
# Name: 2023-06-28 11:20:00, dtype: object
# 68
# 69
# symbol      NSE:COALINDIA
# open               226.35
# high               226.35
# low                 226.2
# close               226.2
# volume            54612.0
# MA5                226.32
# MA50               225.48
# ADX                 25.61
# RSI                  72.0
# RSIMA100            57.69
# Name: 2023-06-28 11:20:00, dtype: object
# 70
# 71
# symbol      NSE:NESTLEIND
# open              22685.0
# high              22685.9
# low              22652.55
# close             22679.8
# volume             1097.0
# MA5              22680.08
# MA50             22628.92
# ADX                  9.18
# RSI                 59.89
# RSIMA100            46.88
# Name: 2023-06-28 11:20:00, dtype: object
# 72
# symbol      NSE:SRF
# open        2313.95
# high        2314.85
# low          2312.5
# close       2313.35
# volume       4114.0
# MA5         2310.74
# MA50        2309.34
# ADX           20.41
# RSI           71.86
# RSIMA100      39.89
# Name: 2023-06-28 11:20:00, dtype: object
# 73
# symbol      NSE:ICICIGI
# open            1324.65
# high            1327.75
# low              1323.0
# close           1327.75
# volume           7250.0
# MA5             1326.07
# MA50             1322.2
# ADX                8.16
# RSI               71.79
# RSIMA100          57.88
# Name: 2023-06-28 11:20:00, dtype: object
# 74
# symbol      NSE:HAVELLS
# open             1287.4
# high             1287.4
# low             1286.45
# close            1287.1
# volume           5907.0
# MA5             1287.39
# MA50            1290.71
# ADX               15.86
# RSI                39.5
# RSIMA100          47.04
# Name: 2023-06-28 11:20:00, dtype: object
# 75
# symbol      NSE:SUNPHARMA
# open              1007.45
# high              1008.35
# low                1007.2
# close              1007.4
# volume            18695.0
# MA5               1007.57
# MA50              1002.28
# ADX                 24.49
# RSI                 71.39
# RSIMA100            60.55
# Name: 2023-06-28 11:20:00, dtype: object
# 76
# 77
# symbol      NSE:APOLLOHOSP
# open                5125.9
# high                5127.0
# low                 5124.1
# close               5124.1
# volume              4368.0
# MA5                5128.05
# MA50               5134.65
# ADX                   9.18
# RSI                  31.72
# RSIMA100             57.16
# Name: 2023-06-28 11:20:00, dtype: object
# 78
# symbol      NSE:LICI
# open          617.15
# high           617.5
# low            617.1
# close         617.45
# volume        3937.0
# MA5            617.9
# MA50          617.99
# ADX            26.01
# RSI            18.26
# RSIMA100       41.84
# Name: 2023-06-28 11:20:00, dtype: object
# 79
# 80
# symbol      NSE:CHOLAFIN
# open              1104.2
# high             1106.95
# low               1103.8
# close            1106.95
# volume           17801.0
# MA5               1104.4
# MA50              1097.0
# ADX                30.61
# RSI                62.09
# RSIMA100           55.65
# Name: 2023-06-28 11:20:00, dtype: object
# 81
# 82
# symbol      NSE:PIIND
# open           3854.0
# high          3856.55
# low            3853.4
# close          3854.1
# volume          139.0
# MA5           3854.65
# MA50          3842.71
# ADX             22.45
# RSI              36.2
# RSIMA100        44.02
# Name: 2023-06-28 11:20:00, dtype: object
# 83
# symbol      NSE:DRREDDY
# open            5070.75
# high             5072.0
# low              5070.0
# close            5070.4
# volume           5248.0
# MA5             5070.98
# MA50             5045.3
# ADX               23.47
# RSI               67.97
# RSIMA100          54.48
# Name: 2023-06-28 11:20:00, dtype: object
# 84
# symbol      NSE:TECHM
# open          1118.35
# high           1120.0
# low            1118.3
# close          1119.2
# volume        10684.0
# MA5           1118.42
# MA50          1116.97
# ADX             27.55
# RSI             59.71
# RSIMA100        49.28
# Name: 2023-06-28 11:20:00, dtype: object
# 85
# symbol      NSE:MOTHERSON
# open                 84.7
# high                84.75
# low                 84.65
# close                84.7
# volume            48009.0
# MA5                 84.79
# MA50                 84.9
# ADX                 34.18
# RSI                 41.67
# RSIMA100            51.61
# Name: 2023-06-28 11:20:00, dtype: object
# 86
# symbol      NSE:ADANIGREEN
# open                 945.9
# high                 947.6
# low                 943.75
# close                947.6
# volume             40474.0
# MA5                  945.9
# MA50                949.51
# ADX                  26.53
# RSI                  62.98
# RSIMA100             40.08
# Name: 2023-06-28 11:20:00, dtype: object
# 87
# 88
# symbol      NSE:ADANIENT
# open             2403.55
# high              2405.0
# low               2400.0
# close             2402.1
# volume           37425.0
# MA5              2402.57
# MA50             2341.79
# ADX                15.31
# RSI                66.33
# RSIMA100           51.47
# Name: 2023-06-28 11:20:00, dtype: object
# 89
# symbol      NSE:HINDALCO
# open               420.1
# high               420.8
# low                420.0
# close             420.65
# volume           36098.0
# MA5               419.98
# MA50              418.53
# ADX                23.62
# RSI                80.36
# RSIMA100           52.86
# Name: 2023-06-28 11:20:00, dtype: object
# 90
# symbol      NSE:DLF
# open          485.2
# high          485.3
# low           485.0
# close         485.3
# volume       7945.0
# MA5          485.34
# MA50         484.57
# ADX           27.55
# RSI           40.21
# RSIMA100      48.21
# Name: 2023-06-28 11:20:00, dtype: object
# 91
# 92
# symbol      NSE:VBL
# open         794.95
# high          795.1
# low           794.4
# close        794.45
# volume       6516.0
# MA5          794.93
# MA50         800.42
# ADX            38.3
# RSI           30.28
# RSIMA100      41.52
# Name: 2023-06-28 11:20:00, dtype: object
# 93
# symbol      NSE:ADANITRANS
# open                 801.3
# high                 801.4
# low                  798.0
# close                800.0
# volume             12856.0
# MA5                 801.08
# MA50                784.99
# ADX                  47.96
# RSI                  61.89
# RSIMA100             45.95
# Name: 2023-06-28 11:20:00, dtype: object
# 94
# 95
# symbol      NSE:NAUKRI
# open            4440.0
# high            4446.8
# low             4440.0
# close           4446.7
# volume           940.0
# MA5            4445.02
# MA50           4420.84
# ADX              18.37
# RSI              42.77
# RSIMA100         51.33
# Name: 2023-06-28 11:20:00, dtype: object
# 96
# symbol      NSE:ATGL
# open          654.95
# high           655.2
# low           653.55
# close         654.95
# volume       16343.0
# MA5            655.4
# MA50          648.22
# ADX            30.61
# RSI            57.35
# RSIMA100       48.28
# Name: 2023-06-28 11:20:00, dtype: object
# 97
# scan Completed !!!

# %%
min_5_data = pd.read_csv('5-min-NIFTY100-scan.csv')
min_5_data[(min_5_data['MA5'] > min_5_data['MA50']) & (min_5_data['RSI'] > min_5_data['RSIMA100'])]
# Out:
#                   symbol      open      high       low     close       MA5  \
# NSE:HDFCAMC      2063.50   2066.05   2062.80   2065.00   13010.0   2057.79
# NSE:ITC           448.35    448.50    448.35    448.40   33151.0    447.89
# NSE:INDIGO       2570.65   2574.00   2569.30   2572.40    2840.0   2571.72
# NSE:BERGEPAINT    677.45    677.90    677.10    677.10    1170.0    678.04
# NSE:KOTAKBANK    1837.60   1839.40   1836.00   1839.00   25338.0   1837.62
# NSE:INDUSTOWER    165.85    166.50    165.85    166.10  256103.0    164.89
# NSE:HCLTECH      1170.80   1171.70   1170.40   1171.25    3910.0   1170.99
# NSE:MARUTI       9491.45   9503.75   9491.45   9501.20    1150.0   9494.37
# NSE:ULTRACEMCO   8219.80   8220.00   8215.05   8219.90    1553.0   8219.60
# NSE:INDUSINDBK   1330.50   1333.90   1329.40   1333.90   41171.0   1330.69
# NSE:INFY         1290.15   1290.85   1290.05   1290.80   21884.0   1289.55
# NSE:AXISBANK      972.85    974.85    972.85    974.50   51737.0    973.10
# NSE:HDFC         2767.75   2770.00   2767.00   2769.45   26835.0   2767.22
# NSE:ICICIBANK     938.15    939.95    938.00    939.95  154184.0    938.26
# NSE:HDFCBANK     1669.25   1670.45   1668.25   1670.25  153103.0   1669.24
# NSE:CIPLA        1009.80   1010.45   1007.35   1008.50   60284.0   1009.42
# NSE:ACC          1818.00   1819.10   1816.60   1817.75    6005.0   1816.28
# NSE:POWERGRID     251.25    251.40    251.20    251.30   46589.0    251.12
# NSE:HINDUNILVR   2656.10   2657.10   2656.00   2656.60    8576.0   2655.78
# NSE:PIDILITIND   2626.80   2627.00   2622.00   2622.95   13972.0   2625.73
# NSE:CANBK         297.65    298.00    297.60    298.00   16425.0    297.80
# NSE:ASIANPAINT   3343.00   3345.00   3342.90   3344.10    3587.0   3342.57
# NSE:NTPC          188.40    188.40    187.90    188.20  104832.0    187.94
# NSE:TORNTPHARM   1884.15   1888.85   1884.15   1888.80     524.0   1886.53
# NSE:ONGC          158.95    159.10    158.90    159.00   73280.0    158.76
# NSE:RELIANCE     2522.95   2523.25   2522.50   2523.00   19496.0   2522.78
# NSE:BRITANNIA    4997.15   5001.00   4995.45   4999.15    1430.0   4992.47
# NSE:UPL           674.95    675.60    674.80    675.40   33875.0    675.11
# NSE:TCS          3208.20   3209.95   3208.00   3209.95    5363.0   3207.41
# NSE:GODREJCP     1036.25   1040.50   1035.95   1040.50   40952.0   1038.14
# NSE:SBILIFE      1297.95   1303.15   1297.40   1303.00   30419.0   1297.53
# NSE:SBIN          572.30    573.00    571.95    572.85  213780.0    572.47
# NSE:TITAN        3023.65   3025.95   3022.55   3025.75    4266.0   3022.88
# NSE:BPCL          363.00    363.30    362.85    363.20   40609.0    362.27
# NSE:TATAMOTORS    585.35    586.45    585.30    586.00  192244.0    586.57
# NSE:GAIL          104.35    104.45    104.25    104.45   87184.0    104.42
# NSE:ADANIPORTS    740.00    740.20    739.55    740.10   97420.0    739.37
# NSE:LT           2414.60   2416.75   2413.60   2416.75    9688.0   2415.90
# NSE:TATACONSUM    856.60    858.00    856.20    857.85    8942.0    856.71
# NSE:COALINDIA     226.35    226.35    226.20    226.20   54612.0    226.32
# NSE:NESTLEIND   22685.00  22685.90  22652.55  22679.80    1097.0  22680.08
# NSE:SRF          2313.95   2314.85   2312.50   2313.35    4114.0   2310.74
# NSE:ICICIGI      1324.65   1327.75   1323.00   1327.75    7250.0   1326.07
# NSE:SUNPHARMA    1007.45   1008.35   1007.20   1007.40   18695.0   1007.57
# NSE:CHOLAFIN     1104.20   1106.95   1103.80   1106.95   17801.0   1104.40
# NSE:DRREDDY      5070.75   5072.00   5070.00   5070.40    5248.0   5070.98
# NSE:TECHM        1118.35   1120.00   1118.30   1119.20   10684.0   1118.42
# NSE:ADANIENT     2403.55   2405.00   2400.00   2402.10   37425.0   2402.57
# NSE:HINDALCO      420.10    420.80    420.00    420.65   36098.0    419.98
# NSE:BAJAJHLDNG   6977.20   6977.85   6977.20   6977.85       7.0   6981.44
# NSE:ADANITRANS    801.30    801.40    798.00    800.00   12856.0    801.08
# NSE:AWL           412.60    412.65    412.05    412.05    7427.0    412.41
# NSE:ATGL          654.95    655.20    653.55    654.95   16343.0    655.40
#
#                     MA50    ADX    RSI  RSIMA100
# NSE:HDFCAMC      2048.57  18.37  65.83     60.08
# NSE:ITC           446.28  19.39  64.71     49.62
# NSE:INDIGO       2547.23  30.61  61.85     60.29
# NSE:BERGEPAINT    677.76  13.34  56.00     44.70
# NSE:KOTAKBANK    1836.52  19.39  60.00     53.17
# NSE:INDUSTOWER    163.23  11.30  59.56     47.70
# NSE:HCLTECH      1170.31  15.31  62.36     49.17
# NSE:MARUTI       9469.60  15.31  49.87     49.54
# NSE:ULTRACEMCO   8209.59  13.27  55.66     50.79
# NSE:INDUSINDBK   1318.38   7.14  83.54     51.45
# NSE:INFY         1282.13  36.73  88.77     46.25
# NSE:AXISBANK      970.99  22.45  78.33     57.01
# NSE:HDFC         2762.33  15.31  60.12     57.57
# NSE:ICICIBANK     934.81  20.41  61.02     53.39
# NSE:HDFCBANK     1663.02   8.16  76.55     58.42
# NSE:CIPLA        1008.78  18.63  59.44     50.62
# NSE:ACC          1799.36  15.31  51.58     48.45
# NSE:POWERGRID     249.72  33.36  57.38     53.07
# NSE:HINDUNILVR   2653.70  21.43  57.69     51.14
# NSE:PIDILITIND   2623.69   9.18  51.99     41.36
# NSE:CANBK         296.63   6.12  60.71     52.06
# NSE:ASIANPAINT   3327.24  26.53  70.90     51.45
# NSE:NTPC          186.34  71.36  74.44     55.49
# NSE:TORNTPHARM   1879.49  25.55  72.69     45.60
# NSE:ONGC          158.00  53.06  82.76     53.82
# NSE:RELIANCE     2504.68  19.39  67.80     51.91
# NSE:BRITANNIA    4969.78  13.27  79.35     42.33
# NSE:UPL           674.65  24.49  78.18     44.64
# NSE:TCS          3196.50  28.57  76.57     48.70
# NSE:GODREJCP     1036.40  17.11  66.15     45.91
# NSE:SBILIFE      1285.04  37.76  86.70     59.14
# NSE:SBIN          566.15  27.86  88.33     53.56
# NSE:TITAN        2990.57  14.29  64.38     62.03
# NSE:BPCL          360.82  17.82  87.50     51.84
# NSE:TATAMOTORS    576.72  36.73  71.51     51.23
# NSE:GAIL          104.25  20.09  59.26     46.19
# NSE:ADANIPORTS    727.57  26.53  75.07     48.35
# NSE:LT           2398.36  46.70  77.46     52.65
# NSE:TATACONSUM    855.30  12.28  64.23     43.64
# NSE:COALINDIA     225.48  25.61  72.00     57.69
# NSE:NESTLEIND   22628.92   9.18  59.89     46.88
# NSE:SRF          2309.34  20.41  71.86     39.89
# NSE:ICICIGI      1322.20   8.16  71.79     57.88
# NSE:SUNPHARMA    1002.28  24.49  71.39     60.55
# NSE:CHOLAFIN     1097.00  30.61  62.09     55.65
# NSE:DRREDDY      5045.30  23.47  67.97     54.48
# NSE:TECHM        1116.97  27.55  59.71     49.28
# NSE:ADANIENT     2341.79  15.31  66.33     51.47
# NSE:HINDALCO      418.53  23.62  80.36     52.86
# NSE:BAJAJHLDNG   6964.66   7.14  51.47     47.41
# NSE:ADANITRANS    784.99  47.96  61.89     45.95
# NSE:AWL           409.90  21.74  50.33     43.61
# NSE:ATGL          648.22  30.61  57.35     48.28

# %% [markdown]
# # INTRADAY screener stretegy:
# + ##  Criteria :
# + 1. 5 MA - 50 MA should be lie b/w -1 to 1 %.
# + 2. RSI > RSI  MA 100 or vice versa.
# + 3. RSI > 55 or RSI < 45.
# + 4. scan stATR
